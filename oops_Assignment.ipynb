# %% [markdown]
# """
# Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.
#
#
# ANSWER
# class is user represenation of the behaviour and attributes of the object. class helps in resuse and modular programming. whereas object is a copy of the class which may
# have additional charectersticis based on the requirement
#
# for example
#
# When we are dealing with pets application, every pet will have name and its type. the below example shows the pet class which is used foor dog as well as a cat
# """
# class pet:
#     def __init__(self,pet_name,pet_type):
#         self.pet_name=pet_name
#         self.pet_type=pet_type
#
# customer1 = pet("laura","DOG")
# customer2 = pet("lousy","cat")

# %% [markdown]
# """
# Q2. Name the four pillars of OOPs.
#
# ANSWER
# The four pillars are Abstarction,Polymorphism,Inheritence,encapsulation
# """

# %% [markdown]
# """
# Q3. Explain why the __init__() function is used. Give a suitable example.
#
# The __init__ is a sort of constructer where it is initialized first when the class is called for.
# sometimes a class may require minimum information for which the object is created. Those informations are passed in the __init__. Below is the example related
# to blood_Sample. to create the object the class requires basic info
# """
# class blood_sample():
#     def __init__(self,name,age,blood_group):
#         self.name=name
#         self.age=age
#         self.blood_group=blood_group

# %% [markdown]
# """
# Q4. Why self is used in OOPs?
#
#  The self is used to refer the attribute insided the class for static functions cls is used
#
# """

# %% [markdown]
# """
# Q5. What is inheritance? Give an example for each type of inheritance.
#
# Inheritance lets the user to inherit the attributes and functionalities of the other class
# which helps re-usability of code
#
# types of inheritance are
#
# single
# multiple
# multilevel
# hierarchial
# hybrid
# """
#
# ### Single inheritance
#
# class sample1:
#     def sq(self):
#         print("This is sq from sample 1")
#
# class sample2(sample1):
#     def cube(self):
#         print("This is cube")
#
# ### multiple inheritance
#
#
# class sample1:
#     def sq(self):
#         print("This is sq from sample 1")
#
# class sample2:
#     def cube(self):
#         print("This is cube")
#
# class sample3(sample1,sample2):
#     def sqroot(self):
#         print("This is sqroot")
#
# ### multilevel inheritance
#
#
# class sample1:
#     def sq(self):
#         print("This is sq from sample 1")
#
# class sample2(sample1):
#     def cube(self):
#         print("This is cube")
#
# class sample3(sample2):
#     def sqroot(self):
#         print("This is sqroot")
#
# ### Hierarchial inheritance
#
#
# class sample1:
#     def sq(self):
#         print("This is sq from sample 1")
#
# class sample2(sample1):
#     def cube(self):
#         print("This is cube")
#
# class sample3(sample1):
#     def sqroot(self):
#         print("This is sqroot")
#
#
# ### Hybrid inheritance
#
#
# class sample1:
#     def sq(self):
#         print("This is sq from sample 1")
#
# class sample2(sample1):
#     def cube(self):
#         print("This is cube")
#
# class sample3:
#     def sqroot(self):
#         print("This is square root")
#
# class sample(sample2,sample3):
#     def cuberoot(self):
#         print("This is cuberoot")
